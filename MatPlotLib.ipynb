# %% [markdown]
# <a href="https://colab.research.google.com/github/noo-nine/Machine-Learning/blob/main/MatPlotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple **Plot**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot([1,5,4,2])
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16])
plt.title('Squares Plot')
plt.xlabel('number')
plt.ylabel('square')
plt.show()

# %% [markdown]
# # **Changing Original Apperance of The Figure**

# %%
plt.figure(figsize=(4,4))
plt.plot([1,2,3,4], [1,4,9,16])
plt.axis([0, 5, 0,20])
plt.annotate('two square', (3,6))
plt.show()

# %% [markdown]
# # Changing into dots and their colour

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.show()

# %% [markdown]
# Bar Chart

# %%
plt.clf()
# clears everything in the figure

# %%
x = np.arange(4)
y = [6,10,4,8]
plt.bar(x,y)
plt.show()

# %%
x = [1,2,3,4]
y = [6,10,4,8]
plt.bar(x,y)
plt.show()

# %%
x = [1,2,3,4]
y = [6,10,4,8]
plt.xticks(x, ['A', 'B', 'C', 'D'])
plt.yticks(y, ['', 'High','', ''])
plt.bar(x,y)
plt.show()

# %%
#adding colors
x = [1,2,3,4]
y = [6,10,4,8]
plt.bar(x, y, color = 'y')
plt.show()

# %%
x = [1,2,3,4]
y = [6,10,4,8]
plt.bar(x, y, color = ['lime', 'r', 'lime', 'r'])
plt.show()

# %% [markdown]
# # **Plotting Two Sets Of Random Numbers**

# %%
d = {'Red 0' : np.random.rand(10),
     'Grn S' : np.random.rand(10)}
df = pd.DataFrame(d)
df.plot(style = ['ro', 'gs'])
plt.show()

# %% [markdown]
# # **Time Series**

# %%
ts = pd.Series(np.random.randn(1000), index = pd.date_range('1/1/2000', periods = 1000))
ts = ts.cumsum()
ts.plot()
plt.show()

# %% [markdown]
# # **Random Dots for a Scatter**

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y)
plt.show()

# %%
#varying sizes
x = np.random.rand(50)
y = np.random.rand(50)
area = np.pi * (np.random.rand(50))** 2
plt.scatter(x,y, s = area)
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
area = np.pi * (20 * np.random.rand(50)) ** 2
plt.scatter(x, y, s = area)
plt.show()

# %%
# adding colors
x = np.random.rand(50)
y = np.random.rand(50)
area = np.pi * (20 * np.random.rand(50)) ** 2
colors = np.random.rand(50)
plt.scatter(x , y, s = area, c = colors)
plt.show()

# %% [markdown]
# # **Importing some Data and PLotting**

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
plt.bar(drinks['country'], drinks['beer_servings'], color = 'c')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.bar(drinks['beer_servings'], drinks['total_litres_of_pure_alcohol'], color = 'c')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # **Subplots**

# %%
fig = plt.figure()
fig.add_subplot(221)
plt.plot([1,2,3])
fig.add_subplot(222)
plt.plot([4,2,3])
fig.add_subplot(223)
plt.plot([1,2,4])
plt.show()

# %%
fig = plt.figure()
fig.add_subplot(222)
plt.plot([1,2,3])
fig.add_subplot(221)
plt.plot([4,2,3])
fig.add_subplot(223)
plt.plot([1,2,4])
plt.show()

# %% [markdown]
# # Saving figure to image File

# %%
plt.plot([1,2,3])
plt.savefig('sampleplot.png')
